# %% [markdown]
# # ORIE 5730 Final Project LSTM Section Code - Cash Included

# %% [markdown]
# ### 1. Data Preparation

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from keras.regularizers import l1, l2

# %%
seed = 4
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)
import sys
sys.path.append('D:\\Cornell\\Spring 2024\\ORIE 5370\\Project')

# Load the data
df = pd.read_excel('combined stock returns.xlsx', index_col='Date', parse_dates=True)

returns_columns = ['AAPL_Return', 'AB_Return', 'DIS_Return', 'GOOG_Return',
                   'MSFT_Return', 'NVDA_Return', 'PYPL_Return', 'TSLA_Return']
prices_columns = ['AAPL', 'AB', 'DIS', 'GOOG', 'MSFT', 'NVDA', 'PYPL', 'TSLA']

# Add CASH to the prices_columns and returns_columns
prices_columns.append('CASH')
returns_columns.append('CASH_Return')

# Add CASH data to the DataFrame
df['CASH'] = 1.0  # Price of cash remains constant
df['CASH_Return'] = 0.04/20  # Assuming a very small return, like interest

all_features = pd.concat([df[returns_columns], df[prices_columns]], axis=1)


split_point = int(len(all_features) * 0.8)
end_point = int(len(all_features) * 0.992)
train_data = all_features[:split_point]
test_data = all_features[split_point:end_point]

# Data Scalling
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data)
test_scaled = scaler.transform(test_data)

def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

# Define sequence length and generate sequences
sequence_length = 60
X_train, y_train = create_sequences(train_scaled, sequence_length)
X_test, y_test = create_sequences(test_scaled, sequence_length)
# print(df.head())
# print(df.shape)

# Plotting the prices of all stocks
plt.figure(figsize=(12, 8))
plt.plot(df['AAPL'], label='AAPL')
plt.plot(df['AB'], label='AB')
plt.plot(df['DIS'], label='DIS')
plt.plot(df['GOOG'], label='GOOG')
plt.plot(df['MSFT'], label='MSFT')
plt.plot(df['NVDA'], label='NVDA')
plt.plot(df['PYPL'], label='PYPL')
plt.plot(df['TSLA'], label='TSLA')
# plt.plot(df['CASH'], label='CASH')
plt.title('Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()  
plt.grid(True)
plt.show()

# %%
all_features.head()
# Out:
#             AAPL_Return  AB_Return  DIS_Return  GOOG_Return  MSFT_Return  \
# Date
# 2015-07-08    -0.024823  -0.015432   -0.016311    -0.015599    -0.001354
# 2015-07-09    -0.020396   0.000348    0.003559     0.007449     0.006329
# 2015-07-10     0.026734   0.006616    0.007267     0.018149     0.002022
# 2015-07-13     0.019305  -0.002421    0.013827     0.030973     0.020847
# 2015-07-14    -0.000398  -0.021151   -0.001694     0.026622     0.001757
#
#             NVDA_Return  PYPL_Return  TSLA_Return  CASH_Return       AAPL  \
# Date
# 2015-07-08    -0.007074    -0.052430    -0.048231        0.002  27.617405
# 2015-07-09    -0.012214    -0.005764     0.011610        0.002  27.054110
# 2015-07-10     0.017517     0.005507     0.004769        0.002  27.777388
# 2015-07-13     0.006582     0.060248     0.011615        0.002  28.313641
# 2015-07-14     0.000503     0.004078     0.013312        0.002  28.302372
#
#                    AB         DIS       GOOG       MSFT      NVDA       PYPL  \
# Date
# 2015-07-08  13.559929  107.632240  25.841499  38.723919  4.757431  34.700001
# 2015-07-09  13.564651  108.015335  26.034000  38.969006  4.699323  34.500000
# 2015-07-10  13.654389  108.800232  26.506500  39.047791  4.781640  34.689999
# 2015-07-13  13.621328  110.304596  27.327499  39.861828  4.813115  36.779999
# 2015-07-14  13.333221  110.117714  28.055000  39.931854  4.815536  36.930000
#
#                  TSLA  CASH
# Date
# 2015-07-08  16.997334   1.0
# 2015-07-09  17.194668   1.0
# 2015-07-10  17.276667   1.0
# 2015-07-13  17.477333   1.0
# 2015-07-14  17.709999   1.0

# %% [markdown]
# ### 2. Optimization

# %%
model = Sequential()
# Add LSTM layers
model.add(LSTM(90, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2]), 
               kernel_regularizer=l2(0.1))) 
model.add(Dropout(0.2))


# Add Dense layers for output prediction
model.add(Dense(y_train.shape[1]))
model.add(Dense(y_train.shape[1], kernel_regularizer=l2(0.01)))

# Compile the model with Adam optimizer and mean squared error loss
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# C:\Users\james\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 2.9525 - val_loss: 1.2804
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9644 - val_loss: 0.4218
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3122 - val_loss: 0.1647
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1207 - val_loss: 0.0908
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0642 - val_loss: 0.0682
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0446 - val_loss: 0.0595
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0320 - val_loss: 0.0494
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0251 - val_loss: 0.0439
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0186 - val_loss: 0.0397
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0160 - val_loss: 0.0394
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0118 - val_loss: 0.0405
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0104 - val_loss: 0.0358
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0081 - val_loss: 0.0380
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0072 - val_loss: 0.0364
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0075 - val_loss: 0.0343
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0061 - val_loss: 0.0351
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0057 - val_loss: 0.0362
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0057 - val_loss: 0.0379
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0055 - val_loss: 0.0325
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0048 - val_loss: 0.0316
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 0.0339
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0049 - val_loss: 0.0359
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0053 - val_loss: 0.0339
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0053 - val_loss: 0.0356
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0053 - val_loss: 0.0353
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0054 - val_loss: 0.0303
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0046 - val_loss: 0.0330
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 0.0335
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0044 - val_loss: 0.0321
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0047 - val_loss: 0.0325

# %%
print(len(X_test)/len(X_train))
print(len(X_train))
# Out:
# 0.21348973607038124
# 1705

# %%
history_df = pd.DataFrame(history.history)
history_df.plot()
# Out:
# <Axes: >

# %%
def sharpe_ratio(weights, returns):
    portfolio_return = np.dot(returns.mean(), weights) * 252
    portfolio_std = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))
    return -portfolio_return / portfolio_std  # Negative because we minimize this function

# %%
# Optimization set-up
num_assets = len(prices_columns)
initial_weights = np.full(num_assets, 1.0 / num_assets)
bounds = [(0.0, 1) if asset == 'CASH' else (0.0, 1/5) for asset in prices_columns]
# bounds = [ (0.0, 0.2) for asset in prices_columns]

constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1}]

rebalance_period = 20

optimal_weights = []
rebalance_dates = []

for i in range(0, len(X_test), rebalance_period):
    start_idx = i
    end_idx = min(i + rebalance_period, len(X_test))
    
    current_period_X = X_test[start_idx:end_idx]
    predicted_returns = model.predict(current_period_X)
    actual_length = current_period_X.shape[0]
    predicted_returns_only = predicted_returns[:actual_length, :len(returns_columns)]
    predicted_returns_df = pd.DataFrame(predicted_returns_only, columns=returns_columns)

    if start_idx + sequence_length < len(test_data):
        rebalance_date = test_data.index[start_idx + sequence_length]
        rebalance_dates.append(rebalance_date)

    # Perform portfolio optimization
    results = minimize(sharpe_ratio, initial_weights, args=(predicted_returns_df,),
                       method='SLSQP', bounds=bounds, constraints=constraints)
    optimal_weights.append(results.x)

    if end_idx == len(X_test):
        break


optimal_weights_df = pd.DataFrame(optimal_weights, columns=returns_columns, index=rebalance_dates)
print(rebalance_dates)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [Timestamp('2022-10-05 00:00:00'), Timestamp('2022-11-02 00:00:00'), Timestamp('2022-12-01 00:00:00'), Timestamp('2022-12-30 00:00:00'), Timestamp('2023-01-31 00:00:00'), Timestamp('2023-03-01 00:00:00'), Timestamp('2023-03-29 00:00:00'), Timestamp('2023-04-27 00:00:00'), Timestamp('2023-05-25 00:00:00'), Timestamp('2023-06-26 00:00:00'), Timestamp('2023-07-25 00:00:00'), Timestamp('2023-08-22 00:00:00'), Timestamp('2023-09-20 00:00:00'), Timestamp('2023-10-18 00:00:00'), Timestamp('2023-11-15 00:00:00'), Timestamp('2023-12-14 00:00:00'), Timestamp('2024-01-16 00:00:00'), Timestamp('2024-02-13 00:00:00'), Timestamp('2024-03-13 00:00:00')]

# %%
optimal_weights_df.sort_index(inplace=True)
# print(optimal_weights_df)

# %% [markdown]
# ### 3. LSTM with Cash

# %%
## Backtest of optimal portfolio
initial_capital = 100000
print(test_data)
initial_prices = df.loc[test_data.index[0], prices_columns].values

portfolio_values_0 = [initial_capital] 

for date in optimal_weights_df.index:
    weights = optimal_weights_df.loc[date].values
    prices = df.loc[date, prices_columns].values
    
    normalized_value = np.sum(weights * prices) / np.sum(weights * initial_prices)
    portfolio_value = normalized_value * initial_capital
    portfolio_values_0.append(portfolio_value)

portfolio_values_df_0 = pd.DataFrame(portfolio_values_0, columns=['Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))
# Out:
#             AAPL_Return  AB_Return  DIS_Return  GOOG_Return  MSFT_Return  \
# Date
# 2022-07-12     0.006834  -0.000244   -0.000427    -0.014358    -0.040982
# 2022-07-13    -0.002537  -0.005608   -0.007051    -0.023183    -0.003745
# 2022-07-14     0.020482  -0.008583   -0.011836    -0.006658     0.005381
# 2022-07-15     0.011450   0.014840    0.036585     0.011908     0.010391
# 2022-07-18    -0.020643  -0.027297    0.005252    -0.025335    -0.009622
# ...                 ...        ...         ...          ...          ...
# 2024-03-12     0.002779   0.008923    0.001336     0.004894     0.026599
# 2024-03-13    -0.012123   0.005307    0.000356     0.008237    -0.000433
# 2024-03-14     0.010927  -0.021408   -0.003911     0.025360     0.024380
# 2024-03-15    -0.002197  -0.002397   -0.000982    -0.015034    -0.020695
# 2024-03-18     0.006372   0.005707    0.016972     0.044383     0.002161
#
#             NVDA_Return  PYPL_Return  TSLA_Return  CASH_Return        AAPL  \
# Date
# 2022-07-12    -0.004620     0.013623    -0.005434        0.002  144.423889
# 2022-07-13     0.005437    -0.000980     0.017033        0.002  144.057526
# 2022-07-14     0.013717    -0.025364     0.005372        0.002  147.008179
# 2022-07-15     0.025371     0.062689     0.007357        0.002  148.691422
# 2022-07-18     0.021507     0.002976     0.001999        0.002  145.621979
# ...                 ...          ...          ...          ...         ...
# 2024-03-12     0.071572    -0.000832    -0.001294        0.002  173.229996
# 2024-03-13    -0.011152     0.040313    -0.045398        0.002  171.130005
# 2024-03-14    -0.032392     0.008807    -0.041185        0.002  173.000000
# 2024-03-15    -0.001217    -0.002381     0.006585        0.002  172.619995
# 2024-03-18     0.007036     0.021957     0.062542        0.002  173.720001
#
#                    AB         DIS        GOOG        MSFT        NVDA  \
# Date
# 2022-07-12  35.793514   93.295937  114.849503  249.740967  150.662720
# 2022-07-13  35.592770   92.638084  112.186996  248.805695  151.481857
# 2022-07-14  35.287289   91.541656  111.440002  250.144608  153.559708
# 2022-07-15  35.810970   94.890739  112.766998  252.743774  157.455627
# 2022-07-18  34.833435   95.389114  109.910004  250.311981  160.842087
# ...               ...         ...         ...         ...         ...
# 2024-03-12  33.919998  112.459999  139.619995  415.279999  919.130005
# 2024-03-13  34.099998  112.500000  140.770004  415.100006  908.880005
# 2024-03-14  33.369999  112.059998  144.339996  425.220001  879.440002
# 2024-03-15  33.290001  111.949997  142.169998  416.420013  878.369995
# 2024-03-18  33.480000  113.849998  148.479996  417.320007  884.549988
#
#                  PYPL        TSLA  CASH
# Date
# 2022-07-12  71.430000  233.070007   1.0
# 2022-07-13  71.360001  237.039993   1.0
# 2022-07-14  69.550003  238.313339   1.0
# 2022-07-15  73.910004  240.066666   1.0
# 2022-07-18  74.129997  240.546661   1.0
# ...               ...         ...   ...
# 2024-03-12  60.029999  177.539993   1.0
# 2024-03-13  62.450001  169.479996   1.0
# 2024-03-14  63.000000  162.500000   1.0
# 2024-03-15  62.849998  163.570007   1.0
# 2024-03-18  64.230003  173.800003   1.0
#
# [424 rows x 18 columns]

# %% [markdown]
# ### 3. Metrices

# %%
portfolio_df = portfolio_values_df_0
# Calculate annual returns
portfolio_df['Month'] = portfolio_df.index.month
Monthly_returns = portfolio_df['Portfolio Value']/portfolio_df['Portfolio Value'].shift(1)-1

# Calculate cumulative return
cumulative_return = portfolio_df['Portfolio Value'].iloc[-1] / portfolio_df['Portfolio Value'].iloc[0] - 1
# Calculate running maximum of the portfolio value
portfolio_df['Running Max'] = portfolio_df['Portfolio Value'].cummax()

# Calculate drawdown: how much the portfolio has fallen from the running maximum
portfolio_df['Drawdown'] = (portfolio_df['Running Max'] - portfolio_df['Portfolio Value']) / portfolio_df['Running Max']

# Calculate maximum drawdown
max_drawdown = portfolio_df['Drawdown'].max()
print("Annual Returns:")
print(Monthly_returns)
print("\nCumulative Return:", cumulative_return)
# Output maximum drawdown
print("Maximum Drawdown:", max_drawdown)
# Out:
# Annual Returns:
# 2022-07-12         NaN
# 2022-10-05   -0.036214
# 2022-11-02   -0.060771
# 2022-12-01    0.229877
# 2022-12-30   -0.150385
# 2023-01-31    0.014704
# 2023-03-01    0.072727
# 2023-03-29    0.169103
# 2023-04-27    0.048172
# 2023-05-25    0.145422
# 2023-06-26   -0.009774
# 2023-07-25   -0.121101
# 2023-08-22    0.084934
# 2023-09-20   -0.002943
# 2023-10-18   -0.007688
# 2023-11-15    0.281252
# 2023-12-14    0.006575
# 2024-01-16    0.012079
# 2024-02-13    0.043890
# 2024-03-13    0.001222
# Name: Portfolio Value, dtype: float64
#
# Cumulative Return: 0.8417907766103971
# Maximum Drawdown: 0.15038505208213562

# %% [markdown]
# ### 4. Enhanced Simple LSTM

# %%
initial_capital = 100000
print("Test data:")
print(test_data)
initial_prices = df.loc[test_data.index[0], prices_columns].values

# List to hold the portfolio values
portfolio_values = [initial_capital] 
historical_max = initial_capital+10000  # Start with initial capital as the initial historical maximum

# Data structures for weights and rebalance dates
weights = initial_weights  # Start with the initial weights defined elsewhere in your setup

for date in optimal_weights_df.index:
    prices = df.loc[date, prices_columns].values
    normalized_value = np.sum(weights * prices) / np.sum(weights * initial_prices)
    portfolio_value = normalized_value * initial_capital
    
    # Check if current portfolio value is a new historical maximum
    if portfolio_value > historical_max:
        historical_max = portfolio_value  # Update historical maximum
        print(f"New historical max reached on {date}: {portfolio_value}")
    else:
        # Only update weights if not at a historical maximum
        weights = optimal_weights_df.loc[date].values  # Update weights from the dataframe of optimal weights
    
    # Append the current or updated portfolio value
    portfolio_values.append(portfolio_value)

# Create a DataFrame from the portfolio values
portfolio_values_df = pd.DataFrame(portfolio_values, columns=['Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))
# Out:
# Test data:
#             AAPL_Return  AB_Return  DIS_Return  GOOG_Return  MSFT_Return  \
# Date
# 2022-07-12     0.006834  -0.000244   -0.000427    -0.014358    -0.040982
# 2022-07-13    -0.002537  -0.005608   -0.007051    -0.023183    -0.003745
# 2022-07-14     0.020482  -0.008583   -0.011836    -0.006658     0.005381
# 2022-07-15     0.011450   0.014840    0.036585     0.011908     0.010391
# 2022-07-18    -0.020643  -0.027297    0.005252    -0.025335    -0.009622
# ...                 ...        ...         ...          ...          ...
# 2024-03-12     0.002779   0.008923    0.001336     0.004894     0.026599
# 2024-03-13    -0.012123   0.005307    0.000356     0.008237    -0.000433
# 2024-03-14     0.010927  -0.021408   -0.003911     0.025360     0.024380
# 2024-03-15    -0.002197  -0.002397   -0.000982    -0.015034    -0.020695
# 2024-03-18     0.006372   0.005707    0.016972     0.044383     0.002161
#
#             NVDA_Return  PYPL_Return  TSLA_Return  CASH_Return        AAPL  \
# Date
# 2022-07-12    -0.004620     0.013623    -0.005434        0.002  144.423889
# 2022-07-13     0.005437    -0.000980     0.017033        0.002  144.057526
# 2022-07-14     0.013717    -0.025364     0.005372        0.002  147.008179
# 2022-07-15     0.025371     0.062689     0.007357        0.002  148.691422
# 2022-07-18     0.021507     0.002976     0.001999        0.002  145.621979
# ...                 ...          ...          ...          ...         ...
# 2024-03-12     0.071572    -0.000832    -0.001294        0.002  173.229996
# 2024-03-13    -0.011152     0.040313    -0.045398        0.002  171.130005
# 2024-03-14    -0.032392     0.008807    -0.041185        0.002  173.000000
# 2024-03-15    -0.001217    -0.002381     0.006585        0.002  172.619995
# 2024-03-18     0.007036     0.021957     0.062542        0.002  173.720001
#
#                    AB         DIS        GOOG        MSFT        NVDA  \
# Date
# 2022-07-12  35.793514   93.295937  114.849503  249.740967  150.662720
# 2022-07-13  35.592770   92.638084  112.186996  248.805695  151.481857
# 2022-07-14  35.287289   91.541656  111.440002  250.144608  153.559708
# 2022-07-15  35.810970   94.890739  112.766998  252.743774  157.455627
# 2022-07-18  34.833435   95.389114  109.910004  250.311981  160.842087
# ...               ...         ...         ...         ...         ...
# 2024-03-12  33.919998  112.459999  139.619995  415.279999  919.130005
# 2024-03-13  34.099998  112.500000  140.770004  415.100006  908.880005
# 2024-03-14  33.369999  112.059998  144.339996  425.220001  879.440002
# 2024-03-15  33.290001  111.949997  142.169998  416.420013  878.369995
# 2024-03-18  33.480000  113.849998  148.479996  417.320007  884.549988
#
#                  PYPL        TSLA  CASH
# Date
# 2022-07-12  71.430000  233.070007   1.0
# 2022-07-13  71.360001  237.039993   1.0
# 2022-07-14  69.550003  238.313339   1.0
# 2022-07-15  73.910004  240.066666   1.0
# 2022-07-18  74.129997  240.546661   1.0
# ...               ...         ...   ...
# 2024-03-12  60.029999  177.539993   1.0
# 2024-03-13  62.450001  169.479996   1.0
# 2024-03-14  63.000000  162.500000   1.0
# 2024-03-15  62.849998  163.570007   1.0
# 2024-03-18  64.230003  173.800003   1.0
#
# [424 rows x 18 columns]
# New historical max reached on 2023-01-31 00:00:00: 110062.04484187794
# New historical max reached on 2023-03-01 00:00:00: 114276.35405520529
# New historical max reached on 2023-03-29 00:00:00: 127857.3609834013
# New historical max reached on 2023-04-27 00:00:00: 133267.26180385397
# New historical max reached on 2023-05-25 00:00:00: 155248.4492518739
# New historical max reached on 2023-06-26 00:00:00: 160629.68463149152
# New historical max reached on 2023-07-25 00:00:00: 174157.5125686376
# New historical max reached on 2024-01-16 00:00:00: 188794.00296943975
# New historical max reached on 2024-02-13 00:00:00: 214373.17307246663
# New historical max reached on 2024-03-13 00:00:00: 240122.30492684545

# %%
portfolio_values_df
# Out:
#             Portfolio Value
# 2022-07-12    100000.000000
# 2022-10-05     99916.039286
# 2022-11-02     90521.606510
# 2022-12-01    102274.435290
# 2022-12-30     95009.642278
# 2023-01-31    110062.044842
# 2023-03-01    114276.354055
# 2023-03-29    127857.360983
# 2023-04-27    133267.261804
# 2023-05-25    155248.449252
# 2023-06-26    160629.684631
# 2023-07-25    174157.512569
# 2023-08-22    168243.034582
# 2023-09-20    136054.195633
# 2023-10-18    135008.154508
# 2023-11-15    146622.520451
# 2023-12-14    171805.159485
# 2024-01-16    188794.002969
# 2024-02-13    214373.173072
# 2024-03-13    240122.304927

# %%
portfolio_df = portfolio_values_df
# Calculate annual returns
portfolio_df['Month'] = portfolio_df.index.month
Monthly_returns = portfolio_df['Portfolio Value']/portfolio_df['Portfolio Value'].shift(1)-1

# Calculate cumulative return
cumulative_return = portfolio_df['Portfolio Value'].iloc[-1] / portfolio_df['Portfolio Value'].iloc[0] - 1
# Calculate running maximum of the portfolio value
portfolio_df['Running Max'] = portfolio_df['Portfolio Value'].cummax()

# Calculate drawdown: how much the portfolio has fallen from the running maximum
portfolio_df['Drawdown'] = (portfolio_df['Running Max'] - portfolio_df['Portfolio Value']) / portfolio_df['Running Max']

# Calculate maximum drawdown
max_drawdown = portfolio_df['Drawdown'].max()
print("Annual Returns:")
print(Monthly_returns)
print("\nCumulative Return:", cumulative_return)
# Output maximum drawdown
print("Maximum Drawdown:", max_drawdown)
# Out:
# Annual Returns:
# 2022-07-12         NaN
# 2022-10-05   -0.000840
# 2022-11-02   -0.094023
# 2022-12-01    0.129835
# 2022-12-30   -0.071032
# 2023-01-31    0.158430
# 2023-03-01    0.038290
# 2023-03-29    0.118844
# 2023-04-27    0.042312
# 2023-05-25    0.164941
# 2023-06-26    0.034662
# 2023-07-25    0.084217
# 2023-08-22   -0.033961
# 2023-09-20   -0.191323
# 2023-10-18   -0.007688
# 2023-11-15    0.086027
# 2023-12-14    0.171752
# 2024-01-16    0.098884
# 2024-02-13    0.135487
# 2024-03-13    0.120114
# Name: Portfolio Value, dtype: float64
#
# Cumulative Return: 1.4012230492684545
# Maximum Drawdown: 0.22479281819909228

# %%
# # Initialize variables
# initial_capital = 100000
# print("Test data:")
# print(test_data)
# initial_prices = df.loc[test_data.index[0], prices_columns[:-1]].values  # Exclude CASH for equal weights calculation

# # List to hold the portfolio values
# portfolio_values = [initial_capital] 
# historical_max = initial_capital  # Start with initial capital as the initial historical maximum
# num_stocks = len(prices_columns) - 1  # Number of stocks excluding CASH

# # Equal weights for the stocks, excluding CASH
# equal_weights = np.full(num_stocks, 1.0 / num_stocks)

# # Start with initial optimized weights
# weights = initial_weights  # Start with the initial weights defined elsewhere in your setup

# for date in optimal_weights_df.index:
#     prices = df.loc[date, prices_columns[:-1]].values  # Exclude CASH for calculation
    
#     # Calculate current portfolio value with current weights
#     normalized_value = np.sum(weights[:-1] * prices) / np.sum(weights[:-1] * initial_prices)  # Exclude CASH weight
#     portfolio_value = normalized_value * initial_capital
    
#     # Calculate equal weight portfolio value for comparison
#     equal_weight_normalized_value = np.sum(equal_weights * prices) / np.sum(equal_weights * initial_prices)
#     equal_weight_portfolio_value = equal_weight_normalized_value * initial_capital

#     # Check if current portfolio value is a new historical maximum
#     if portfolio_value > historical_max:
#         historical_max = portfolio_value  # Update historical maximum
#         print(f"New historical max reached on {date}: {portfolio_value}")
#     elif portfolio_value < equal_weight_portfolio_value:
#         # If the portfolio value is less than the equal weight portfolio, switch to equal weights
#         weights[:-1] = equal_weights  # Update weights to equal for stocks, keep CASH weight
#         print(f"Switching to equal weights on {date} due to underperformance.")
#     else:
#         # Only update weights if not at a historical maximum and not underperforming equal weight portfolio
#         weights = optimal_weights_df.loc[date].values  # Update weights from the dataframe of optimal weights
    
#     # Append the current or updated portfolio value
#     portfolio_values.append(portfolio_value)

# # Create a DataFrame from the portfolio values
# portfolio_values_df = pd.DataFrame(portfolio_values, columns=['Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))

# %%
plt.figure(figsize=(14, 7))
plt.plot(portfolio_values_df.index, portfolio_values_df['Portfolio Value'], linestyle='-', marker ='o', color='b')
plt.title('Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value in $')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Equal-weighted Portfolio

# %%
initial_capital = 100000
initial_prices = df.loc[test_data.index[0], prices_columns[:-1]].values  # Exclude 'CASH'

# Ensure only the stock prices are considered
num_assets = len(prices_columns) - 1  # Explicitly exclude CASH
equal_weights = np.full(num_assets, 1.0 / num_assets)

# List to hold the portfolio values
equal_weighted_portfolio_values = []

# Calculate initial portfolio value

equal_weighted_portfolio_values.append(initial_capital)

# %%
portfolio_df = equal_weighted_portfolio_values


# Calculate cumulative return
cumulative_return = portfolio_df[-1] / portfolio_df[0] - 1
# Calculate running maximum of the portfolio value
# portfolio_df['Running Max'] = portfolio_df['Portfolio Value'].cummax()

# # Calculate drawdown: how much the portfolio has fallen from the running maximum
# portfolio_df['Drawdown'] = (portfolio_df['Running Max'] - portfolio_df['Portfolio Value']) / portfolio_df['Running Max']

# Calculate maximum drawdown
# max_drawdown = portfolio_df['Drawdown'].max()
print("Annual Returns:")

print("\nCumulative Return:", cumulative_return)
# Output maximum drawdown
print("Maximum Drawdown:", max_drawdown)
# Out:
# Annual Returns:
#
# Cumulative Return: 0.8380055805183764
# Maximum Drawdown: 0.15038505208213562

# %%
# Loop over the test data indices
for date in test_data.index:
    prices = df.loc[date, prices_columns[:-1]].values  # Exclude 'CASH'
    
    portfolio_value = np.sum(equal_weights * prices) * initial_capital / np.sum(equal_weights * initial_prices)
    equal_weighted_portfolio_values.append(portfolio_value)

# Create a DataFrame from the values
equal_weighted_portfolio_values_df = pd.DataFrame(equal_weighted_portfolio_values, columns=['Portfolio Value'], index=[test_data.index[0]] + list(test_data.index))
# Plotting
plt.figure(figsize=(14, 8))
plt.plot(equal_weighted_portfolio_values_df.index, equal_weighted_portfolio_values_df['Portfolio Value'], linestyle='-', color='r')
plt.title('Equal-Weighted Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value in $')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Comparison with Equal-weighted

# %%
plt.figure(figsize=(14, 7))
plt.plot(equal_weighted_portfolio_values_df.index, equal_weighted_portfolio_values_df['Portfolio Value'], linestyle='--', color='r')
plt.plot(portfolio_values_df.index, portfolio_values_df['Portfolio Value'], linestyle='-',marker ='o'  ,color='b')
plt.plot(portfolio_values_df_0.index, portfolio_values_df_0['Portfolio Value'], linestyle='-',marker ='o'  ,color='g')
plt.legend(['Equal-Weighted Portfolio', 'LSTM Portfolio Enhanced', 'LSTM Portfolio with Cash'])
plt.title('Equal-Weighted Portfolio Value Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value in $')
plt.grid(True)
plt.show()

# %%
initial_capital = 100000
initial_prices = df.loc[test_data.index[0], prices_columns].values

num_assets = len(prices_columns)
equal_weights = np.full(num_assets, 1.0 / num_assets)

# Initialize portfolio values for all strategies
switching_portfolio_values = [initial_capital]
no_switching_portfolio_values = [initial_capital]
equal_weighted_portfolio_values = [initial_capital]

current_weights = equal_weights  # Start with equal weights for switching strategy
current_strategy = "equal"  # Start with equal weight strategy for switching strategy

for date in optimal_weights_df.index:
    prices = df.loc[date, prices_columns].values

    # Calculate portfolio value for equal weights
    equal_normalized_value = np.sum(equal_weights * prices) / np.sum(equal_weights * initial_prices)
    equal_portfolio_value = equal_normalized_value * initial_capital

    # Calculate portfolio value for optimal weights
    if date in optimal_weights_df.index:
        optimal_weights = optimal_weights_df.loc[date].values
    optimal_normalized_value = np.sum(optimal_weights * prices) / np.sum(optimal_weights * initial_prices)
    optimal_portfolio_value = optimal_normalized_value * initial_capital

    # Append values for the no-switching optimal strategy
    no_switching_portfolio_values.append(optimal_portfolio_value)

    # Append values computed with the current strategy for switching
    if current_strategy == "optimal":
        switching_portfolio_values.append(optimal_portfolio_value)
    else:
        switching_portfolio_values.append(equal_portfolio_value)

    # Decide which strategy to use for the next period in the switching strategy
    if optimal_portfolio_value < equal_portfolio_value:
        current_weights = equal_weights
        current_strategy = "equal"
    else:
        current_weights = optimal_weights
        current_strategy = "optimal"

    equal_weighted_portfolio_values.append(equal_portfolio_value)

# Create DataFrames to store the portfolio values
switching_portfolio_values_df = pd.DataFrame(switching_portfolio_values, columns=['Switching Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))
no_switching_portfolio_values_df = pd.DataFrame(no_switching_portfolio_values, columns=['No-Switching Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))
equal_weighted_portfolio_values_df = pd.DataFrame(equal_weighted_portfolio_values, columns=['Equal Weighted Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))

# Plotting all strategies for comparison
plt.figure(figsize=(14, 7))
plt.plot(switching_portfolio_values_df.index, switching_portfolio_values_df['Switching Portfolio Value'], linestyle='-', color='b', label='Switching Strategy')
plt.plot(no_switching_portfolio_values_df.index, no_switching_portfolio_values_df['No-Switching Portfolio Value'], linestyle='--', color='g', label='No-Switching Optimal Strategy')
plt.plot(equal_weighted_portfolio_values_df.index, equal_weighted_portfolio_values_df['Equal Weighted Portfolio Value'], linestyle='-', color='r', label='Equal Weight Strategy')
plt.title('Comparison of Different Portfolio Strategies Over Time')
plt.xlabel('Date')
plt.ylabel('Portfolio Value in $')
plt.legend()
plt.grid(True)
plt.show()

# %%
initial_capital = 100000
print(test_data)
initial_prices = df.loc[test_data.index[0], prices_columns].values

portfolio_values = [initial_capital]
cash = initial_capital  # Cash held after selling stocks
in_market = True  # Whether we are currently invested in the stocks

for date in optimal_weights_df.index:
    weights = optimal_weights_df.loc[date].values
    prices = df.loc[date, prices_columns].values
    
    normalized_value = np.sum(weights * prices) / np.sum(weights * initial_prices)
    portfolio_value = normalized_value * initial_capital
    portfolio_values.append(portfolio_value)

# Implementing revised strategy
portfolio_values_df = pd.DataFrame(portfolio_values, columns=['Portfolio Value'], index=[test_data.index[0]] + list(optimal_weights_df.index))
portfolio_values_df['SMA_10'] = portfolio_values_df['Portfolio Value'].rolling(window=5).mean()

# Signals
portfolio_values_df['Sell_Signal'] = (portfolio_values_df['Portfolio Value'] < portfolio_values_df['SMA_10']).astype(int).rolling(window=3).sum() == 3
portfolio_values_df['Buy_Signal'] = (portfolio_values_df['Portfolio Value'] > portfolio_values_df['SMA_10']).astype(int).rolling(window=3).sum() == 3

# Applying signals
for i in range(1, len(portfolio_values_df)):
    if portfolio_values_df['Sell_Signal'].iloc[i] and in_market:
        cash = portfolio_values_df['Portfolio Value'].iloc[i]
        in_market = False
    elif portfolio_values_df['Buy_Signal'].iloc[i] and not in_market:
        initial_capital = cash  # Reinvest the cash held
        in_market = True
    portfolio_values_df['Portfolio Value'].iloc[i] = cash if not in_market else portfolio_values_df['Portfolio Value'].iloc[i]
# Out:
#             AAPL_Return  AB_Return  DIS_Return  GOOG_Return  MSFT_Return  \
# Date
# 2022-07-12     0.006834  -0.000244   -0.000427    -0.014358    -0.040982
# 2022-07-13    -0.002537  -0.005608   -0.007051    -0.023183    -0.003745
# 2022-07-14     0.020482  -0.008583   -0.011836    -0.006658     0.005381
# 2022-07-15     0.011450   0.014840    0.036585     0.011908     0.010391
# 2022-07-18    -0.020643  -0.027297    0.005252    -0.025335    -0.009622
# ...                 ...        ...         ...          ...          ...
# 2024-04-08    -0.006664   0.019825   -0.008701     0.014291    -0.002186
# 2024-04-09     0.007243  -0.014580    0.005283     0.012809     0.003980
# 2024-04-10    -0.011139  -0.035103   -0.006612    -0.003035    -0.007085
# 2024-04-11     0.043271  -0.005111   -0.000341     0.019853     0.011033
# 2024-04-12     0.008627   0.001813   -0.026803    -0.009951    -0.014091
#
#             NVDA_Return  PYPL_Return  TSLA_Return  CASH_Return        AAPL  \
# Date
# 2022-07-12    -0.004620     0.013623    -0.005434        0.002  144.423889
# 2022-07-13     0.005437    -0.000980     0.017033        0.002  144.057526
# 2022-07-14     0.013717    -0.025364     0.005372        0.002  147.008179
# 2022-07-15     0.025371     0.062689     0.007357        0.002  148.691422
# 2022-07-18     0.021507     0.002976     0.001999        0.002  145.621979
# ...                 ...          ...          ...          ...         ...
# 2024-04-08    -0.009942     0.018265     0.048999        0.002  168.449997
# 2024-04-09    -0.020417     0.009949     0.022546        0.002  169.669998
# 2024-04-10     0.019741    -0.016716    -0.028946        0.002  167.779999
# 2024-04-11     0.041096    -0.001214     0.016535        0.002  175.039993
# 2024-04-12    -0.026816    -0.018389    -0.020332        0.002  176.550003
#
#                    AB         DIS        GOOG        MSFT        NVDA  \
# Date
# 2022-07-12  35.793514   93.295937  114.849503  249.740967  150.662720
# 2022-07-13  35.592770   92.638084  112.186996  248.805695  151.481857
# 2022-07-14  35.287289   91.541656  111.440002  250.144608  153.559708
# 2022-07-15  35.810970   94.890739  112.766998  252.743774  157.455627
# 2022-07-18  34.833435   95.389114  109.910004  250.311981  160.842087
# ...               ...         ...         ...         ...         ...
# 2024-04-08  34.980000  117.349998  156.139999  424.589996  871.330017
# 2024-04-09  34.470001  117.970001  158.139999  426.279999  853.539978
# 2024-04-10  33.259998  117.190002  157.660004  423.260010  870.390015
# 2024-04-11  33.090000  117.150002  160.789993  427.929993  906.159973
# 2024-04-12  33.150002  114.010002  159.190002  421.899994  881.859985
#
#                  PYPL        TSLA  CASH
# Date
# 2022-07-12  71.430000  233.070007   1.0
# 2022-07-13  71.360001  237.039993   1.0
# 2022-07-14  69.550003  238.313339   1.0
# 2022-07-15  73.910004  240.066666   1.0
# 2022-07-18  74.129997  240.546661   1.0
# ...               ...         ...   ...
# 2024-04-08  66.339996  172.979996   1.0
# 2024-04-09  67.000000  176.880005   1.0
# 2024-04-10  65.879997  171.759995   1.0
# 2024-04-11  65.800003  174.600006   1.0
# 2024-04-12  64.589996  171.050003   1.0
#
# [442 rows x 18 columns]
# C:\Users\james\AppData\Local\Temp\ipykernel_10980\1602417793.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   portfolio_values_df['Portfolio Value'].iloc[i] = cash if not in_market else portfolio_values_df['Portfolio Value'].iloc[i]

# %%
portfolio_values_df.plot()
# Out:
# <Axes: >
